# %%
import pandas as pd
student_dict={'Name':['pierre','Rabil','Sara'], 'Age':[23,45,40],'Weight':[60,70,80]}
student_df=pd.DataFrame(student_dict)
student_df
# Out:
#      Name  Age  Weight
# 0  pierre   23      60
# 1   Rabil   45      70
# 2    Sara   40      80

# %%
student_df=student_df.set_index('Name')
student_df
# Out:
#         Age  Weight
# Name
# pierre   23      60
# Rabil    45      70
# Sara     40      80

# %%
student_df=student_df.reset_index()
student_df
# Out:
#      Name  Age  Weight
# 0  pierre   23      60
# 1   Rabil   45      70
# 2    Sara   40      80

# %%
student_df=student_df.dropna()
student_df
# Out:
#      Name  Age  Weight
# 0  pierre   23      60
# 1   Rabil   45      70
# 2    Sara   40      80

# %%
student_df=student_df.reset_index()
student_df
# Out:
#    index    Name  Age  Weight
# 0      0  pierre   23      60
# 1      1   Rabil   45      70
# 2      2    Sara   40      80

# %%
pip install --upgrade regex
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from gapminder import gapminder
gapminder.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
pip install gapminder
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
gapminder.set_index(['continent','country','year'], inplace=True)
gapminder.head()
# Out:
#                             lifeExp       pop   gdpPercap
# continent country     year
# Asia      Afghanistan 1952   28.801   8425333  779.445314
#                       1957   30.332   9240934  820.853030
#                       1962   31.997  10267083  853.100710
#                       1967   34.020  11537966  836.197138
#                       1972   36.088  13079460  739.981106

# %%
gapminder.loc['Europe']
# Out:
#                      lifeExp       pop     gdpPercap
# country        year
# Albania        1952   55.230   1282697   1601.056136
#                1957   59.280   1476505   1942.284244
#                1962   64.820   1728137   2312.888958
#                1967   66.220   1984060   2760.196931
#                1972   67.690   2263554   3313.422188
# ...                      ...       ...           ...
# United Kingdom 1987   75.007  56981620  21664.787670
#                1992   76.420  57866349  22705.092540
#                1997   77.218  58808266  26074.531360
#                2002   78.471  59912431  29478.999190
#                2007   79.425  60776238  33203.261280
#
# [360 rows x 3 columns]

# %%
gapminder.loc[('Europe','United Kingdom',2007)]
# Out:
# lifeExp      7.942500e+01
# pop          6.077624e+07
# gdpPercap    3.320326e+04
# Name: (Europe, United Kingdom, 2007), dtype: float64

# %%
gapminder_pivot=gapminder.unstack()
gapminder_pivot
# Out:
#                          lifeExp                                          \
# year                        1952    1957    1962    1967    1972    1977
# continent country
# Africa    Algeria         43.077  45.685  48.303  51.407  54.518  58.014
#           Angola          30.015  31.999  34.000  35.985  37.928  39.483
#           Benin           38.223  40.358  42.618  44.885  47.014  49.190
#           Botswana        47.622  49.618  51.520  53.298  56.024  59.319
#           Burkina Faso    31.975  34.906  37.814  40.697  43.591  46.137
# ...                          ...     ...     ...     ...     ...     ...
# Europe    Switzerland     69.620  70.560  71.320  72.770  73.780  75.390
#           Turkey          43.585  48.079  52.098  54.336  57.005  59.507
#           United Kingdom  69.180  70.420  70.760  71.360  72.010  72.760
# Oceania   Australia       69.120  70.330  70.930  71.100  71.930  73.490
#           New Zealand     69.390  70.260  71.240  71.520  71.890  72.220
#
# ...

# %%
gapminder_pivot=gapminder.stack()
gapminder_pivot
# Out:
# continent  country      year
# Asia       Afghanistan  1952  lifeExp      2.880100e+01
#                               pop          8.425333e+06
#                               gdpPercap    7.794453e+02
#                         1957  lifeExp      3.033200e+01
#                               pop          9.240934e+06
#                                                ...
# Africa     Zimbabwe     2002  pop          1.192656e+07
#                               gdpPercap    6.720386e+02
#                         2007  lifeExp      4.348700e+01
#                               pop          1.231114e+07
#                               gdpPercap    4.697093e+02
# Length: 5112, dtype: float64

# %%
import pandas as pd
s=pd.Series([3,5,7,6,9,12,4])
resultat=s.isin([3,6])
resultat
# Out:
# 0     True
# 1    False
# 2    False
# 3     True
# 4    False
# 5    False
# 6    False
# dtype: bool

# %%
file_name='C:/Users/Admin/Downloads/nyc-parking-violations-2020.csv'
df=pd.read_csv(file_name,usecols=['Date First Observed', 'Plate ID', 'Registration State', 'Vehicle Make', 'Street Name', 'Vehicle Color'])
df.head()
