# %%
import pandas as pd
from pandas import Series, DataFrame

filename ='C:/Users/2376234/Desktop/data/nyc-parking-violations-2020.csv'
df= pd.read_csv(filename , usecols =['Plate ID', 'Registration State','Vehicle Make', 'Street Name', 'Vehicle Color','Violation Time'])
df.head()
# Out:
#   Plate ID Registration State Vehicle Make Violation Time      Street Name  \
# 0   J58JKX                 NJ        HONDA          0523P            43 ST
# 1  KRE6058                 PA        ME/BE          0428P         UNION ST
# 2  444326R                 NJ        LEXUS          0625A  CLERMONT AVENUE
# 3  F728330                 OH        CHEVR          1106A     DIVISION AVE
# 4  FMY9090                 NY         JEEP          1253A         GRAND ST
#
#   Vehicle Color
# 0            BK
# 1           BLK
# 2         BLACK
# 3           NaN
# 4          GREY

# %%
len(df)
# Out:
# 10401807

# %%
s=df.shape
s
# Out:
# (10401807, 6)

# %%
pd.isnull(df)
# Out:
#           Plate ID  Registration State  Vehicle Make  Violation Time  \
# 0            False               False         False           False
# 1            False               False         False           False
# 2            False               False         False           False
# 3            False               False         False           False
# 4            False               False         False           False
# ...            ...                 ...           ...             ...
# 10401802     False               False         False           False
# 10401803     False               False         False           False
# 10401804     False               False         False           False
# 10401805     False               False         False           False
# 10401806      True                True          True            True
#
#           Street Name  Vehicle Color
# 0               False          False
# 1               False          False
# ...

# %%
df2=df.dropna()
df2
# Out:
#          Plate ID Registration State Vehicle Make Violation Time  \
# 0          J58JKX                 NJ        HONDA          0523P
# 1         KRE6058                 PA        ME/BE          0428P
# 2         444326R                 NJ        LEXUS          0625A
# 4         FMY9090                 NY         JEEP          1253A
# 5         KDG0693                 PA         HYUN          0525P
# ...           ...                ...          ...            ...
# 10401801  HTA9375                 NY        CHRYS          0850A
# 10401802  JJH9818                 NY        CADIL          0847A
# 10401803  JDZ7197                 NY        ME/BE          0846A
# 10401804  JBR5409                 NY        NISSA          0840A
# 10401805  HXA2016                 NY        TOYOT          0839A
#
#                    Street Name Vehicle Color
# 0                        43 ST            BK
# 1                     UNION ST           BLK
# 2              CLERMONT AVENUE         BLACK
# ...

# %%
pd.isnull(df2)
# Out:
#           Plate ID  Registration State  Vehicle Make  Street Name  \
# 0            False               False         False        False
# 1            False               False         False        False
# 2            False               False         False        False
# 4            False               False         False        False
# 5            False               False         False        False
# ...            ...                 ...           ...          ...
# 10401801     False               False         False        False
# 10401802     False               False         False        False
# 10401803     False               False         False        False
# 10401804     False               False         False        False
# 10401805     False               False         False        False
#
#           Vehicle Color
# 0                 False
# 1                 False
# 2                 False
# 4                 False
# 5                 False
# ...

# %%
len(df2)
# Out:
# 10114156

# %%
df3=len(df)-len(df2)
df3
# Out:
# 287651

# %%
df4=df.isna().sum()
df4
# Out:
# Plate ID                 197
# Registration State         1
# Vehicle Make           57331
# Street Name             1243
# Vehicle Color         236861
# dtype: int64

# %%
df5=len(df)-df3
df5
# Out:
# 10114156

# %%
df6=df3*100
df6
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df6=df3*100
#       2 df6
#
# NameError: name 'df3' is not defined

# %%
import pandas as pd
from pandas import Series, DataFrame

filename ='C:/Users/2376234/Downloads/celebrity_deaths_2016.csv'
df= pd.read_csv(filename,usecols=['dateofdeath','age'])
df.head()
# Out:
#   dateofdeath age
# 0  2016-01-01  71
# 1  2016-01-01  74
# 2  2016-01-01  79
# 3  2016-01-01  45
# 4  2016-01-01  83

# %%
#Q2
df['month']=df['dateofdeath'].str.slice(5,7)
df
# Out:
#      dateofdeath age month
# 0     2016-01-01  71    01
# 1     2016-01-01  74    01
# 2     2016-01-01  79    01
# 3     2016-01-01  45    01
# 4     2016-01-01  83    01
# ...          ...  ..   ...
# 6538  2016-12-27  74    12
# 6539  2016-12-27  85    12
# 6540  2016-12-27  83    12
# 6541  2016-12-27  23    12
# 6542  2016-12-27  84    12
#
# [6543 rows x 3 columns]

# %%
#Q3
df2=df.set_index('month')
df2
# Out:
#       dateofdeath age
# month
# 01     2016-01-01  71
# 01     2016-01-01  74
# 01     2016-01-01  79
# 01     2016-01-01  45
# 01     2016-01-01  83
# ...           ...  ..
# 12     2016-12-27  74
# 12     2016-12-27  85
# 12     2016-12-27  83
# 12     2016-12-27  23
# 12     2016-12-27  84
#
# [6543 rows x 2 columns]

# %%
#Q4
df3=df.sort_index()
df3
# Out:
#      dateofdeath age month
# 0     2016-01-01  71    01
# 1     2016-01-01  74    01
# 2     2016-01-01  79    01
# 3     2016-01-01  45    01
# 4     2016-01-01  83    01
# ...          ...  ..   ...
# 6538  2016-12-27  74    12
# 6539  2016-12-27  85    12
# 6540  2016-12-27  83    12
# 6541  2016-12-27  23    12
# 6542  2016-12-27  84    12
#
# [6543 rows x 3 columns]

# %%
df4=df2.sort_index()
df4
# Out:
#       dateofdeath age
# month
# 01     2016-01-01  71
# 01     2016-01-21  47
# 01     2016-01-21  87
# 01     2016-01-21  90
# 01     2016-01-21  73
# ...           ...  ..
# 12     2016-12-10  63
# 12     2016-12-10  20
# 12     2016-12-10  57
# 12     2016-12-10  78
# 12     2016-12-27  84
#
# [6543 rows x 2 columns]

# %%
df3['age'].dropna
# Out:
#      dateofdeath age month
# 0     2016-01-01  71    01
# 1     2016-01-01  74    01
# 2     2016-01-01  79    01
# 3     2016-01-01  45    01
# 4     2016-01-01  83    01
# ...          ...  ..   ...
# 6538  2016-12-27  74    12
# 6539  2016-12-27  85    12
# 6540  2016-12-27  83    12
# 6541  2016-12-27  23    12
# 6542  2016-12-27  84    12
#
# [6543 rows x 3 columns]

# %%
#Q5
df=df.dropna(subset=['age'])
df=df[df['age'].str.isdigit()]
df
# Out:
#       dateofdeath age
# month
# 01     2016-01-01  71
# 01     2016-01-21  47
# 01     2016-01-21  87
# 01     2016-01-21  90
# 01     2016-01-21  73
# ...           ...  ..
# 12     2016-12-10  63
# 12     2016-12-10  20
# 12     2016-12-10  57
# 12     2016-12-10  78
# 12     2016-12-27  84
#
# [6481 rows x 2 columns]

# %%
df['age'].str.isdigit()
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 6538    True
# 6539    True
# 6540    True
# 6541    True
# 6542    True
# Name: age, Length: 6481, dtype: bool

# %%
df['age']=pd.to_numeric(df['age'],errors='coerce')
df
# Out:
#       dateofdeath  age
# month
# 01     2016-01-01   71
# 01     2016-01-21   47
# 01     2016-01-21   87
# 01     2016-01-21   90
# 01     2016-01-21   73
# ...           ...  ...
# 12     2016-12-10   63
# 12     2016-12-10   20
# 12     2016-12-10   57
# 12     2016-12-10   78
# 12     2016-12-27   84
#
# [6481 rows x 2 columns]

# %%
#Q7
import numpy as np
df['age']=df['age'].astype(np.int64)
df
# Out:
#       dateofdeath  age
# month
# 01     2016-01-01   71
# 01     2016-01-21   47
# 01     2016-01-21   87
# 01     2016-01-21   90
# 01     2016-01-21   73
# ...           ...  ...
# 12     2016-12-10   63
# 12     2016-12-10   20
# 12     2016-12-10   57
# 12     2016-12-10   78
# 12     2016-12-27   84
#
# [6481 rows x 2 columns]

# %%
df.describe()
# Out:
#                age
# count  6481.000000
# mean     77.019287
# std      16.428815
# min       7.000000
# 25%      69.000000
# 50%      81.000000
# 75%      89.000000
# max     116.000000

# %%
df['age'].describe()
# Out:
# count    6481.000000
# mean       77.019287
# std        16.428815
# min         7.000000
# 25%        69.000000
# 50%        81.000000
# 75%        89.000000
# max       116.000000
# Name: age, dtype: float64

# %%
df.info() #Seluement utilise pour le Data Frame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6481 entries, 01 to 12
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   dateofdeath  6481 non-null   object
#  1   age          6481 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 151.9+ KB

# %%
df[df['age']< 120]
# Out:
#       dateofdeath  age
# month
# 01     2016-01-01   71
# 01     2016-01-21   47
# 01     2016-01-21   87
# 01     2016-01-21   90
# 01     2016-01-21   73
# ...           ...  ...
# 12     2016-12-10   63
# 12     2016-12-10   20
# 12     2016-12-10   57
# 12     2016-12-10   78
# 12     2016-12-27   84
#
# [6481 rows x 2 columns]

# %%
#Q10
df.loc['02':'07', 'age'].mean()
# Out:
# 77.17887409200968
