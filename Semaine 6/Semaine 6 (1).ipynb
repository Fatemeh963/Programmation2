# %%
import pandas as pd

 

data = {'A': [11, 22, 33],
        'B': [44, 55, 66],
        'C': [77, 88, 99]
        }

 

df = pd.DataFrame(data, columns = ['A', 'B', 'C'])
df
# Out:
#     A   B   C
# 0  11  44  77
# 1  22  55  88
# 2  33  66  99

# %%
df.transpose()
# Out:
#     0   1   2
# A  11  22  33
# B  44  55  66
# C  77  88  99

# %%
df.T
# Out:
#     0   1   2
# A  11  22  33
# B  44  55  66
# C  77  88  99

# %%
df.rolling(window=2).C.sum()
# Out:
# 0      NaN
# 1    165.0
# 2    187.0
# Name: C, dtype: float64

# %%
df.rolling(window=2,min_periods=1).C.sum()
# Out:
# 0     77.0
# 1    165.0
# 2    187.0
# Name: C, dtype: float64

# %%
df.rolling(window=2,min_periods=1).mean()
# Out:
#       A     B     C
# 0  11.0  44.0  77.0
# 1  16.5  49.5  82.5
# 2  27.5  60.5  93.5

# %%
s=pd.Series([90,91,85])
s
# Out:
# 0    90
# 1    91
# 2    85
# dtype: int64

# %%
s.pct_change()
# Out:
# 0         NaN
# 1    0.011111
# 2   -0.065934
# dtype: float64

# %%
import pandas as pd
from pandas import Series, DataFrame

filename ='C:/Users/2376234/Downloads/complete.csv'
df= pd.read_csv(filename, usecols=['awardYear', 'category', 'prizeAmount', 'prizeAmountAdjusted', 'name', 'gender', 'birth_continent'])
df.head()
# Out:
#    awardYear           category  prizeAmount  prizeAmountAdjusted  \
# 0       2001  Economic Sciences     10000000             12295082
# 1       1975            Physics       630000              3404179
# 2       2004          Chemistry     10000000             11762861
# 3       1982          Chemistry      1150000              3102518
# 4       1979            Physics       800000              2988048
#
#                 name gender birth_continent
# 0  A. Michael Spence   male   North America
# 1       Aage N. Bohr   male          Europe
# 2  Aaron Ciechanover   male            Asia
# 3         Aaron Klug   male          Europe
# 4        Abdus Salam   male            Asia

# %%
grouped=df.groupby('category')
print(type(grouped))
# Out:
# <class 'pandas.core.groupby.generic.DataFrameGroupBy'>

# %%
grouped.indices
# Out:
# {'Chemistry': array([  2,   3,   7,   9,  10,  11,  13,  14,  15,  17,  19,  39,  62,
#          64,  66,  71,  75,  80,  81,  86,  92, 104, 107, 112, 129, 135,
#         153, 169, 175, 178, 181, 188, 197, 199, 203, 210, 215, 223, 227,
#         239, 247, 249, 258, 264, 265, 268, 272, 274, 280, 282, 284, 289,
#         296, 298, 310, 311, 317, 318, 337, 341, 343, 348, 352, 357, 362,
#         365, 366, 372, 374, 384, 394, 395, 396, 415, 416, 419, 434, 440,
#         442, 444, 446, 448, 450, 455, 456, 459, 461, 463, 465, 469, 475,
#         504, 505, 508, 518, 522, 523, 524, 539, 549, 558, 559, 563, 567,
#         571, 572, 585, 591, 596, 599, 627, 630, 632, 641, 643, 644, 648,
#         659, 661, 666, 667, 668, 671, 673, 679, 681, 686, 713, 715, 717,
#         719, 720, 722, 723, 725, 726, 729, 732, 738, 742, 744, 746, 751,
#         756, 759, 763, 766, 773, 776, 798, 810, 813, 814, 817, 827, 828,
#         829, 832, 839, 848, 853, 855, 862, 866, 880, 885, 886, 888, 889,
# ...

# %%
grouped.groups
# Out:
# {'Chemistry': [2, 3, 7, 9, 10, 11, 13, 14, 15, 17, 19, 39, 62, 64, 66, 71, 75, 80, 81, 86, 92, 104, 107, 112, 129, 135, 153, 169, 175, 178, 181, 188, 197, 199, 203, 210, 215, 223, 227, 239, 247, 249, 258, 264, 265, 268, 272, 274, 280, 282, 284, 289, 296, 298, 310, 311, 317, 318, 337, 341, 343, 348, 352, 357, 362, 365, 366, 372, 374, 384, 394, 395, 396, 415, 416, 419, 434, 440, 442, 444, 446, 448, 450, 455, 456, 459, 461, 463, 465, 469, 475, 504, 505, 508, 518, 522, 523, 524, 539, 549, ...], 'Economic Sciences': [0, 5, 45, 46, 58, 90, 96, 139, 140, 145, 152, 156, 157, 180, 187, 193, 207, 219, 231, 232, 246, 250, 269, 279, 283, 295, 305, 324, 346, 369, 418, 422, 425, 426, 430, 432, 438, 458, 467, 476, 485, 510, 525, 527, 537, 538, 546, 580, 594, 595, 605, 611, 636, 637, 657, 669, 670, 678, 700, 708, 716, 724, 734, 737, 739, 745, 747, 749, 750, 753, 758, 767, 800, 805, 854, 856, 860, 864, 871, 882, 896, 912, 916, 924], 'Literature': [21, 31, 40, 49, 52, 98, 100, 101, 102, 111, 115, 142,
# ...

# %%
grouped_category_year=df.groupby(['category','awardYear'])
print(grouped_category_year)

# %%
print(grouped.ngroups)
# Out:
# 6

# %%
print(len(grouped))
# Out:
# 6

# %%
grouped.get_group('Economic Sciences')
# Out:
#      awardYear           category  prizeAmount  prizeAmountAdjusted  \
# 0         2001  Economic Sciences     10000000             12295082
# 5         2019  Economic Sciences      9000000              9000000
# 45        2012  Economic Sciences      8000000              8361204
# 46        1998  Economic Sciences      7600000              9713701
# 58        2015  Economic Sciences      8000000              8384572
# ..         ...                ...          ...                  ...
# 882       2002  Economic Sciences     10000000             12034660
# 896       1973  Economic Sciences       510000              3331882
# 912       2018  Economic Sciences      9000000              9000000
# 916       1990  Economic Sciences      4000000              6329114
# 924       1996  Economic Sciences      7400000              9490424
#
#                     name gender birth_continent
# 0      A. Michael Spence   male   North America
# 5       Abhijit Banerjee   male            Asia
# ...

# %%
grouped.mean()
# Out:
# C:\Users\2376234\AppData\Local\Temp\ipykernel_12332\2755795945.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   grouped.mean()
#                           awardYear   prizeAmount  prizeAmountAdjusted
# category
# Chemistry               1972.347826  3.629279e+06         6.257868e+06
# Economic Sciences       1996.119048  6.105845e+06         7.837779e+06
# Literature              1960.931034  2.493811e+06         5.598256e+06
# Peace                   1964.537313  3.124879e+06         6.163907e+06
# Physics                 1971.065728  3.407939e+06         6.086978e+06
# Physiology or Medicine  1970.356164  3.072973e+06         5.738301e+06

# %%
grouped.describe()
# Out:
#                        awardYear                                           \
#                            count         mean        std     min      25%
# category
# Chemistry                  184.0  1972.347826  33.852116  1901.0  1946.75
# Economic Sciences           84.0  1996.119048  14.857885  1969.0  1983.75
# Literature                 116.0  1960.931034  34.848423  1901.0  1929.75
# Peace                      134.0  1964.537313  36.414625  1901.0  1931.00
# Physics                    213.0  1971.065728  33.581293  1901.0  1950.00
# Physiology or Medicine     219.0  1970.356164  31.527054  1901.0  1949.00
#
#                                                 prizeAmount                \
#                            50%      75%     max       count          mean
# category
# Chemistry               1979.0  2001.25  2019.0       184.0  3.629279e+06
# Economic Sciences       1997.5  2009.00  2019.0        84.0  6.105845e+06
# ...

# %%
left = pd.DataFrame(
    {"A": ["A0", "A1", "A2"], "B": ["B0", "B1", "B2"]}, index=["K0", "K1", "K2"]
)

 

right = pd.DataFrame(
    {"C": ["C0", "C2", "C3"], "D": ["D0", "D2", "D3"]}, index=["K0", "K2", "K3"]
)

# %%
result= left.join(right,how="left")
result
# Out:
#      A   B    C    D
# K0  A0  B0   C0   D0
# K1  A1  B1  NaN  NaN
# K2  A2  B2   C2   D2

# %%
result=left.join(right)
result
# Out:
#      A   B    C    D
# K0  A0  B0   C0   D0
# K1  A1  B1  NaN  NaN
# K2  A2  B2   C2   D2

# %%
result=left.join(right, how="outer")
result
# Out:
#       A    B    C    D
# K0   A0   B0   C0   D0
# K1   A1   B1  NaN  NaN
# K2   A2   B2   C2   D2
# K3  NaN  NaN   C3   D3

# %%
result=left.join(right, how="inner")
result
# Out:
#      A   B   C   D
# K0  A0  B0  C0  D0
# K2  A2  B2  C2  D2

# %%
import pandas as pd
chart = {'Name':['Chetan','yashas','yuvraj'],'Age':  [20, 25, 30],'Height': [155, 160, 175],'Weight': [55,60,75]}
df = pd.DataFrame(chart)
df
# Out:
#      Name  Age  Height  Weight
# 0  Chetan   20     155      55
# 1  yashas   25     160      60
# 2  yuvraj   30     175      75

# %%
df.corr(method ='pearson')
# Out:
# C:\Users\2376234\AppData\Local\Temp\ipykernel_12332\2355739806.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr(method ='pearson')
#              Age    Height    Weight
# Age     1.000000  0.960769  0.960769
# Height  0.960769  1.000000  1.000000
# Weight  0.960769  1.000000  1.000000

# %%
df = pd.read_csv("https://raw.githubusercontent.com/bprasad26/lwd/master/data/titanic.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.dropna(subset=['Age'],inplace=True)

# %%
df['Age'].min(),df['Age'].max()
# Out:
# (0.42, 80.0)

# %%
bins=[0,14,24,64,100]
df['Agecat']=pd.cut(df['Age'],bin)
df['Agecat']
# Out:
# 0      (14, 24]
# 1      (24, 64]
# 2      (24, 64]
# 3      (24, 64]
# 4      (24, 64]
#          ...
# 885    (24, 64]
# 886    (24, 64]
# 887    (14, 24]
# 889    (24, 64]
# 890    (24, 64]
# Name: Agecat, Length: 714, dtype: category
# Categories (4, interval[int64, right]): [(0, 14] < (14, 24] < (24, 64] < (64, 100]]

# %%
bin=[0,14,24,64,100]
bin_labels=['children','Yong','Adult','Senior']
df['Agecat']=pd.cut(df['Age'], bins=bins, labels=bin_labels)
df['Agecat']
# Out:
# 0       Yong
# 1      Adult
# 2      Adult
# 3      Adult
# 4      Adult
#        ...
# 885    Adult
# 886    Adult
# 887     Yong
# 889    Adult
# 890    Adult
# Name: Agecat, Length: 714, dtype: category
# Categories (4, object): ['children' < 'Yong' < 'Adult' < 'Senior']
